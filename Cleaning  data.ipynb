# %% [markdown]
# ## Converting Data types

# %%
# Importing Pandas
import pandas as pd
import numpy as np

# %%
# Loading the dataset
data_runtime = pd.read_excel("Data/Run Times.xlsx")
data_runtime
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
#  Checking the datatypes of our dataset
data_runtime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          5 non-null      object
#  1   Run Time      5 non-null      float64
#  2   Warm Up Time  5 non-null      object
#  3   Location      5 non-null      object
#  4   Run Date      5 non-null      datetime64[ns]
#  5   Race Date     5 non-null      datetime64[ns]
#  6   Rain          5 non-null      bool
#  7   Fee           5 non-null      object
# dtypes: bool(1), datetime64[ns](2), float64(1), object(4)
# memory usage: 413.0+ bytes

# %%
data_runtime.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                     object
# dtype: object

# %%
# Converting the Fee column to a float64 datatype
data_runtime["Fee"] = data_runtime.Fee.str.replace('$','')
data_runtime
# Out:
# /tmp/ipykernel_9437/1270634367.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_runtime["Fee"] = data_runtime.Fee.str.replace('$','')
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain   Fee
# 0  False  0.00
# 1   True  0.00
# 2  False  2.50
# 3  False  0.00
# 4  False  2.50

# %%
data_runtime.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                     object
# dtype: object

# %%
# After removing the dollar sign we convert the column to float64 datatype
data_runtime.Fee = pd.to_numeric(data_runtime["Fee"])
data_runtime
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain  Fee
# 0  False  0.0
# 1   True  0.0
# 2  False  2.5
# 3  False  0.0
# 4  False  2.5

# %%
# Now if we run the cell the datatype will be of type float
data_runtime.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                    float64
# dtype: object

# %%
# Converting the Warm up time to a numeric dtype
data_runtime["Warm Up Time"] = data_runtime["Warm Up Time"].astype("str").str.replace(" min","")
data_runtime
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209            3  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain  Fee
# 0  False  0.0
# 1   True  0.0
# 2  False  2.5
# 3  False  0.0
# 4  False  2.5

# %%
data_runtime.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                    float64
# dtype: object

# %%
# Converting the Warm Up Time to a numeric data type
data_runtime["Warm Up Time"] = pd.to_numeric(data_runtime["Warm Up Time"])
data_runtime
# Out:
#      Name  Run Time  Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343           3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842           3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209           3.0  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123           2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342           2.0      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain  Fee
# 0  False  0.0
# 1   True  0.0
# 2  False  2.5
# 3  False  0.0
# 4  False  2.5

# %%
data_runtime.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time           float64
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                    float64
# dtype: object

# %%
# Changing the Rain Coloumn to a numeric type
data_runtime.Rain = data_runtime.Rain.astype("int")
data_runtime
# Out:
#      Name  Run Time  Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343           3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842           3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209           3.0  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123           2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342           2.0      “gym” 2023-05-10 16:30:00 2023-06-15
#
#    Rain  Fee
# 0     0  0.0
# 1     1  0.0
# 2     0  2.5
# 3     0  0.0
# 4     0  2.5

# %% [markdown]
# ## Assignment 1

# %%
# Loading in the dataset
df_alarm = pd.read_excel("Data/Alarm Survey Data.xlsx")
df_alarm
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
# Checking the data type of the columns
df_alarm.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating           object
# dtype: object

# %%
# Converting the alarm_rating to numeric data type by first removing the string in it
df_alarm["alarm_rating"] = df_alarm["alarm_rating"].astype("str").str.replace(" stars","")
df_alarm
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1            5
# ...

# %%
df_alarm.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating           object
# dtype: object

# %%
# Converting to numeric data type
df_alarm["alarm_rating"] = pd.to_numeric(df_alarm["alarm_rating"])
df_alarm
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# ...

# %%
# Confirming if alarm_rating is of type int64
df_alarm.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %% [markdown]
# ## Findig Missing Data

# %%
# Loading the data
students = pd.read_excel("Data/Student Grades.xlsx")
students
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 81      NaN               NaN       NaN    NaN
# 82  Bennett               NaN       NaN    NaN
# 83      NaN               EDA    Junior   84.0
# 84    Gavin               EDA    Senior    NaN
# 85   Calvin               NaN       NaN  100.0
#
# [86 rows x 4 columns]

# %%
# Checking the null values
students.Grade.value_counts(dropna=False)
# Out:
# 88.0     6
# 85.0     6
# 84.0     6
# 86.0     5
# 90.0     5
# 80.0     4
# 87.0     4
# NaN      4
# 82.0     4
# 81.0     3
# 77.0     3
# 79.0     3
# 89.0     3
# 83.0     3
# 91.0     3
# 96.0     3
# 93.0     3
# 95.0     2
# 71.0     2
# 76.0     2
# 92.0     2
# 72.0     1
# 64.0     1
# 200.0    1
# 94.0     1
# 45.0     1
# 98.0     1
# 50.0     1
# 74.0     1
# 78.0     1
# 100.0    1
# Name: Grade, dtype: int64

# %%
students.isna()
# Out:
#     Student  Class   Year  Grade
# 0     False  False  False  False
# 1     False  False  False  False
# 2     False  False  False  False
# 3     False  False  False  False
# 4     False  False  False  False
# ..      ...    ...    ...    ...
# 81     True   True   True   True
# 82    False   True   True   True
# 83     True  False  False  False
# 84    False  False  False   True
# 85    False   True   True  False
#
# [86 rows x 4 columns]

# %%
# Checking the number of missing data in every column
students.isna().sum()
# Out:
# Student    2
# Class      3
# Year       6
# Grade      4
# dtype: int64

# %%
# Checking null values using a boolean
# Missing value -> True
# No missing value -> False
students.isna().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# Length: 86, dtype: bool

# %% [markdown]
# ## Handling Missing Data

# %%
# Rows that has missing values
students[students.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 83      NaN                        EDA  Junior   84.0
# 84    Gavin                        EDA  Senior    NaN
# 85   Calvin                        NaN     NaN  100.0

# %%
# Dropping some rows with Student and class missing data
students[students.isna().any(axis=1)].dropna(subset=['Student','Class'])
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
# If we run these command it will erase all the rows with missing data
students[students.isna().any(axis=1)].dropna()
# Out:
# Empty DataFrame
# Columns: [Student, Class, Year, Grade]
# Index: []

# %%
students[students.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 83      NaN                        EDA  Junior   84.0
# 84    Gavin                        EDA  Senior    NaN
# 85   Calvin                        NaN     NaN  100.0

# %%
# Even after we dropped the rows with missing data in class and student our data didn't get updated
# To update our data we need to set the new data back to our dataframe
students = students.dropna(subset=['Student','Class'])
students
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 77    Aaron               EDA    Junior   85.0
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 84    Gavin               EDA    Senior    NaN
#
# [82 rows x 4 columns]

# %%
# Checking whether we still have the data we dropped
students[students.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
# We can use inplace = true to update our dataset everytime a change is made
students.dropna(subset=['Student','Class'],inplace=True)
students
# Out:
# /tmp/ipykernel_9437/3942697498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   students.dropna(subset=['Student','Class'],inplace=True)
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 77    Aaron               EDA    Junior   85.0
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 84    Gavin               EDA    Senior    NaN
#
# [82 rows x 4 columns]

# %%
# We can confirm by checking our data shape
students.shape
# Out:
# (82, 4)

# %% [markdown]
# ## Assignment 2

# %%
# Loading in the dataset
df = pd.read_excel("Data/Alarm Survey Data.xlsx")
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
# Checking for any missing data
df.isna().sum()
# Out:
# survey_id               0
# age                     0
# number_of_children      0
# activity_level          0
# sleep_quality         351
# number_of_snoozes       0
# alarm_rating            0
# dtype: int64

# %%
# Checking which data is missing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
# Checking the null values
df[df.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 10           11   28                 2.0  light_activity            NaN
# 18           19   38                 2.0  lightly active            NaN
# 23           24   24                 2.0     very active            NaN
# 26           27   25                 2.0  lightly active            NaN
# 28           29   29                 2.0  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 6310       6311   30                 2.0     very active            NaN
# 6319       6320   44                 2.0  lightly active            NaN
# 6375       6309   32                 3.0           light            NaN
# 6377       6311   30                 2.0     very active            NaN
# 6386       6320   44                 2.0  lightly active            NaN
#
#       number_of_snoozes alarm_rating
# 10                    3      4 stars
# ...

# %%
# Checking for unique values in the sleep_quality column
# Use argument dropna=False to check which value is NaN
df["sleep_quality"].value_counts(dropna=False)
# Out:
# 5.0    2721
# 4.0    2261
# 3.0     997
# NaN     351
# 1.0     103
# Name: sleep_quality, dtype: int64

# %%
# From the look of value_count progression the NaN values should be a 2
df["sleep_quality"].fillna(2).value_counts(dropna=False)
# Out:
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# 1.0     103
# Name: sleep_quality, dtype: int64

# %%
# Checking whether the data is updated
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
# Using the inplace=True argument
df["sleep_quality"].fillna(2,inplace=True)
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
# After we set the inplace is not true our values becomes updated hence no missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6433 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
# Loading the data
df_std = pd.read_excel("Data/Student Grades.xlsx")
df_std
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 81      NaN               NaN       NaN    NaN
# 82  Bennett               NaN       NaN    NaN
# 83      NaN               EDA    Junior   84.0
# 84    Gavin               EDA    Senior    NaN
# 85   Calvin               NaN       NaN  100.0
#
# [86 rows x 4 columns]

# %%
# Checking the rows that has null values
df_std.isna().sum()
# Out:
# Student    2
# Class      3
# Year       6
# Grade      4
# dtype: int64

# %%
# Checking for unique entries in the Year column
df_std.Year.value_counts()
# Out:
# Freshman     35
# Sophomore    24
# Junior       20
# Senior        1
# Name: Year, dtype: int64

# %%
df_std.Grade.value_counts()
# Out:
# 88.0     6
# 85.0     6
# 84.0     6
# 86.0     5
# 90.0     5
# 82.0     4
# 80.0     4
# 87.0     4
# 79.0     3
# 96.0     3
# 91.0     3
# 83.0     3
# 93.0     3
# 77.0     3
# 81.0     3
# 89.0     3
# 95.0     2
# 71.0     2
# 76.0     2
# 92.0     2
# 45.0     1
# 64.0     1
# 72.0     1
# 200.0    1
# 94.0     1
# 98.0     1
# 50.0     1
# 74.0     1
# 78.0     1
# 100.0    1
# Name: Grade, dtype: int64

# %%
# We want to drop the row that have student missing
df_std.dropna(subset=["Student"],inplace=True)

# %%
df_std
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 82  Bennett               NaN       NaN    NaN
# 84    Gavin               EDA    Senior    NaN
# 85   Calvin               NaN       NaN  100.0
#
# [84 rows x 4 columns]

# %%
# Fill the missing Grades using the median
missing_value = df_std.Grade.median()
missing_value
# Out:
# 85.0

# %%
df_std.Grade.fillna(missing_value,inplace=True)
df_std
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 82  Bennett               NaN       NaN   85.0
# 84    Gavin               EDA    Senior   85.0
# 85   Calvin               NaN       NaN  100.0
#
# [84 rows x 4 columns]

# %%
# Confirming that our column has no missing values
df_std.isna().sum()
# Out:
# Student    0
# Class      2
# Year       0
# Grade      0
# dtype: int64

# %%
# It keeps rows with atleast 3 null values
y = df_std.dropna(thresh = 3)
y
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 77    Aaron               EDA    Junior   85.0
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 84    Gavin               EDA    Senior   85.0
#
# [82 rows x 4 columns]

# %%
y.isna().sum()
# Out:
# Student    0
# Class      0
# Year       3
# Grade      0
# dtype: int64

# %%
df_std.isna().sum()
# Out:
# Student    0
# Class      2
# Year       0
# Grade      0
# dtype: int64

# %%
# Let's fill with the multiple values the Year column
df_std.Year.value_counts()
# Out:
# Freshman     35
# Sophomore    24
# Junior       19
# Senior        6
# Name: Year, dtype: int64

# %%
# Let's fill the missing year with Senior
df_std.Year = np.where(df_std.Year.isna(),"Senior",df_std.Year)
df_std
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 82  Bennett               NaN    Senior   85.0
# 84    Gavin               EDA    Senior   85.0
# 85   Calvin               NaN    Senior  100.0
#
# [84 rows x 4 columns]

# %%
# We can now remove all the missing values using the notna()
df_std[df_std.Class.notna()]
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 77    Aaron               EDA    Junior   85.0
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 84    Gavin               EDA    Senior   85.0
#
# [82 rows x 4 columns]

# %%
df_std.isna().sum()
# Out:
# Student    0
# Class      2
# Year       0
# Grade      0
# dtype: int64

# %%
# Dropping any row with missing data
df_std.dropna(inplace=True)

# %%
df_std
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 77    Aaron               EDA    Junior   85.0
# 78  Charles               EDA    Junior   93.0
# 79   Connor               EDA    Junior   91.0
# 80    Riley               EDA    Junior   87.0
# 84    Gavin               EDA    Senior   85.0
#
# [82 rows x 4 columns]

# %%
# Checking if we still have any null values
df_std.isna().sum()
# Out:
# Student    0
# Class      0
# Year       0
# Grade      0
# dtype: int64
