# %% [markdown]
# ## Data Manipulation Using Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cardio_base.csv")
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0          0  18393       2     168    62.0    110     80            1      0
# 1          1  20228       1     156    85.0    140     90            3      0
# 2          2  18857       1     165    64.0    130     70            3      0
# 3          3  17623       2     169    82.0    150    100            1      0
# 4          4  17474       1     156    56.0    100     60            1      0
# ...      ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995  99993  19240       2     168    76.0    120     80            1      1
# 69996  99995  22601       1     158   126.0    140     90            2      0
# 69997  99996  19066       2     183   105.0    180     90            3      0
# 69998  99998  22431       1     163    72.0    135     80            1      0
# 69999  99999  20540       1     170    72.0    120     80            2      0
#
# [70000 rows x 9 columns]

# %%
#Getting the first rows of the data
df.head(10)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0   0  18393       2     168    62.0    110     80            1      0
# 1   1  20228       1     156    85.0    140     90            3      0
# 2   2  18857       1     165    64.0    130     70            3      0
# 3   3  17623       2     169    82.0    150    100            1      0
# 4   4  17474       1     156    56.0    100     60            1      0
# 5   8  21914       1     151    67.0    120     80            2      0
# 6   9  22113       1     157    93.0    130     80            3      0
# 7  12  22584       2     178    95.0    130     90            3      0
# 8  13  17668       1     158    71.0    110     70            1      0
# 9  14  19834       1     164    68.0    110     60            1      0

# %%
#Getting the last rows of the data
df.tail(10)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 69990  99986  15094       1     168    72.0    110     70            1      0
# 69991  99988  20609       1     159    72.0    130     90            2      0
# 69992  99990  18792       1     161    56.0    170     90            1      0
# 69993  99991  19699       1     172    70.0    130     90            1      0
# 69994  99992  21074       1     165    80.0    150     80            1      0
# 69995  99993  19240       2     168    76.0    120     80            1      1
# 69996  99995  22601       1     158   126.0    140     90            2      0
# 69997  99996  19066       2     183   105.0    180     90            3      0
# 69998  99998  22431       1     163    72.0    135     80            1      0
# 69999  99999  20540       1     170    72.0    120     80            2      0

# %%
#Getting a sample of the data
df.sample(10)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 44192  63129  17609       1     156    68.0    120     80            1      0
# 64854  92570  21017       1     175    84.0    150     75            1      0
# 19965  28516  20385       2     167    83.0    150     90            1      1
# 36709  52466  14326       1     164    45.0    100     70            1      0
# 49949  71296  22696       1     155    61.0    140     80            1      0
# 48794  69671  19813       1     162    73.0    150     90            1      0
# 40540  57932  17323       1     171    70.0    120     70            1      0
# 37925  54143  18056       1     165    67.0    120     80            1      0
# 34374  49114  21844       1     165    65.0    120     80            1      0
# 47230  67469  15300       1     162    74.0    120     80            1      0

# %%
#Checking the empty values and their sum in our dataset
df.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# smoke          0
# dtype: int64

# %%
#Getting the statistics of the data
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol         smoke
# count  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      0.088129
# std      154.011419    188.472530      0.680250      0.283484
# ...

# %%
#Getting the information of our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   smoke        70000 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 4.8 MB

# %%
#Getting the correlation of our data
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
#
#                 ap_lo  cholesterol     smoke
# id          -0.002529     0.006106 -0.003699
# age          0.017647     0.154424 -0.047633
# gender       0.015254    -0.035821  0.338135
# height       0.006150    -0.050226  0.187989
# ...

# %%
#Getting the unique values in our datasets column
df.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# smoke              2
# dtype: int64

# %% [markdown]
# ## Visualization of the datset

# %%
#Lets visualize the whole dataset depending on the different inputs they have.
elements = ["gender", "height", "weight", "ap_hi" ,"ap_lo" ,"cholesterol", "smoke"]
values = [2, 109, 287, 153, 157, 3, 2]

plt.pie(values, labels = elements, autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %%
#Visualization of the id and age

elements = ["id", "age"]
values = [70000, 8076]

plt.pie(values, labels = elements, autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Creating and Training a model

# %%
#Spliting data int x alabels and y target

x = df.drop(["smoke"],axis = 1 )
y = df["smoke"]

print("Spliting done")
# Out:
# Spliting done

# %%
#Importing and trianing the model

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

print("Training Done")
# Out:
# Training Done

# %%
# Finding the optimum number of clusters for k-means classification

x = df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = [] #wcss-the sum of squared distance between each point and the centroid in a cluster.

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %%
# Importing model

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)

print("Fitting Done")
# Out:
# Fitting Done
# /home/danielbrian/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Checking the score of the model

ml_model = model.score(x_test,y_test)
ml_model
# Out:
# 0.9113571428571429

# %%
#Let's predict tthe smoke output given the input attributes
features = np.array([[5,10000,15789,2,200,90,157,100,3]])
print(model.predict(features))

# %%
#Save the model
import pickle 
pickle.dump(model,open("Logistic_regression_model.pk1","wb"))

loaded_model = pickle.load(open("Logistic_regression_model.pk1","rb"))
loaded_model.score(x_test,y_test)
# Out:
# 0.9113571428571429
