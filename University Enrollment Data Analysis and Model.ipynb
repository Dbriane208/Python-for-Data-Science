# %% [markdown]
# ## Data Manipulation using pandas

# %%
#import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the data

df = pd.read_csv("university_enrollment_2306.csv")
df
# Out:
#       course_id course_type  year  enrollment_count pre_score  post_score  \
# 0             1   classroom  2018               165     28.14        73.0
# 1             2   classroom  2020               175     79.68        86.0
# 2             3      online  2016               257     57.24        80.0
# 3             4      online  2013               251     97.67        75.0
# 4             5   classroom  2019               165     39.75        76.0
# ...         ...         ...   ...               ...       ...         ...
# 1845       1846   classroom  2018               155     60.01        81.0
# 1846       1847      online  2016               261     94.27        85.0
# 1847       1848      online  2011               257        76        81.0
# 1848       1849      online  2013               256     20.67        66.0
# 1849       1850      online  2017               256     17.57        72.0
#
#      pre_requirement   department
# 0           Beginner      Science
# ...

# %%
#Getting a random sample of our data
df.sample(10)
# Out:
#       course_id course_type  year  enrollment_count pre_score  post_score  \
# 1120       1121      online  2012               256       5.9        64.0
# 906         907      online  2014               251      80.3        84.0
# 1551       1552   classroom  2021               175     72.04        88.0
# 1296       1297      online  2016               257     34.37        76.0
# 1241       1242      online  2022               251         -        75.0
# 1278       1279   classroom  2019               155     18.57        69.0
# 222         223      online  2021               235     53.47        66.0
# 427         428      online  2011               256     40.16        82.0
# 1499       1500      online  2017               247     77.35        72.0
# 48           49   classroom  2022               165     80.47        84.0
#
#      pre_requirement   department
# 1120            None         Math
# 906         Beginner   Technology
# 1551            None      Science
# ...

# %%
#Getting the shape of our data
df.shape
# Out:
# (1850, 8)

# %%
#Checking the missing values
df.isna().sum()
# Out:
# course_id             0
# course_type           0
# year                  0
# enrollment_count      0
# pre_score             0
# post_score          185
# pre_requirement      89
# department            0
# dtype: int64

# %%
#Dropping the pre_requirement
df = df.drop(["pre_requirement"],axis = 1)
df
# Out:
#       course_id course_type  year  enrollment_count pre_score  post_score  \
# 0             1   classroom  2018               165     28.14        73.0
# 1             2   classroom  2020               175     79.68        86.0
# 2             3      online  2016               257     57.24        80.0
# 3             4      online  2013               251     97.67        75.0
# 4             5   classroom  2019               165     39.75        76.0
# ...         ...         ...   ...               ...       ...         ...
# 1845       1846   classroom  2018               155     60.01        81.0
# 1846       1847      online  2016               261     94.27        85.0
# 1847       1848      online  2011               257        76        81.0
# 1848       1849      online  2013               256     20.67        66.0
# 1849       1850      online  2017               256     17.57        72.0
#
#        department
# 0         Science
# 1         Science
# 2     Mathematics
# ...

# %%
#Filling the missing values of post_score with the mean
df.fillna(np.mean(df["post_score"]),inplace = True)

# %%
#Checking the missing values after filling post score
df.isna().sum()
# Out:
# course_id           0
# course_type         0
# year                0
# enrollment_count    0
# pre_score           0
# post_score          0
# department          0
# dtype: int64

# %%
#Checking the value counts of course_type
df["course_type"].value_counts()
# Out:
# online       1375
# classroom     475
# Name: course_type, dtype: int64

# %%
#Checking the value counts of year
df["year"].value_counts()
# Out:
# 2013    169
# 2012    164
# 2016    162
# 2015    160
# 2021    159
# 2018    156
# 2014    152
# 2022    150
# 2011    148
# 2019    147
# 2017    143
# 2020    140
# Name: year, dtype: int64

# %%
#Checking the sum of course_type column
df["course_type"].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       classroom
# 1       classroom
# 2          online
# 3          online
# 4       classroom
#           ...
# 1845    classroom
# 1846       online
# 1847       online
# 1848       online
# 1849       online
# Name: course_type, Length: 1850, dtype: object>

# %%
#Checking the sum of course_type column
df["year"].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       2018
# 1       2020
# 2       2016
# 3       2013
# 4       2019
#         ...
# 1845    2018
# 1846    2016
# 1847    2011
# 1848    2013
# 1849    2017
# Name: year, Length: 1850, dtype: int64>

# %%
#Checking the value counts of department
df["department"].value_counts()
# Out:
# Technology     719
# Science        472
# Mathematics    220
# Math           220
# Engineering    219
# Name: department, dtype: int64

# %%
#Changing the the categorical values to numeric values
new_df = pd.get_dummies(df,columns = ["department"])
new_df
# Out:
#       course_id course_type  year  enrollment_count pre_score  post_score  \
# 0             1   classroom  2018               165     28.14        73.0
# 1             2   classroom  2020               175     79.68        86.0
# 2             3      online  2016               257     57.24        80.0
# 3             4      online  2013               251     97.67        75.0
# 4             5   classroom  2019               165     39.75        76.0
# ...         ...         ...   ...               ...       ...         ...
# 1845       1846   classroom  2018               155     60.01        81.0
# 1846       1847      online  2016               261     94.27        85.0
# 1847       1848      online  2011               257        76        81.0
# 1848       1849      online  2013               256     20.67        66.0
# 1849       1850      online  2017               256     17.57        72.0
#
#       department_Engineering  department_Math  department_Mathematics  \
# ...

# %%
#Getting the statistics of the data
new_df.describe()
# Out:
#          course_id         year  enrollment_count   post_score  \
# count  1850.000000  1850.000000       1850.000000  1850.000000
# mean    925.500000  2016.423784        231.565405    75.204805
# std     534.193317     3.448278         36.987029     8.074932
# min       1.000000  2011.000000        154.000000    51.000000
# 25%     463.250000  2013.000000        185.000000    70.000000
# 50%     925.500000  2016.000000        251.000000    75.204805
# 75%    1387.750000  2019.000000        261.000000    80.000000
# max    1850.000000  2022.000000        267.000000   105.000000
#
#        department_Engineering  department_Math  department_Mathematics  \
# count             1850.000000      1850.000000             1850.000000
# mean                 0.118378         0.118919                0.118919
# std                  0.323143         0.323781                0.323781
# min                  0.000000         0.000000                0.000000
# ...

# %%
#Getting the new information of our dataset
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   course_id               1850 non-null   int64
#  1   course_type             1850 non-null   object
#  2   year                    1850 non-null   int64
#  3   enrollment_count        1850 non-null   int64
#  4   pre_score               1850 non-null   object
#  5   post_score              1850 non-null   float64
#  6   department_Engineering  1850 non-null   uint8
#  7   department_Math         1850 non-null   uint8
#  8   department_Mathematics  1850 non-null   uint8
#  9   department_Science      1850 non-null   uint8
#  10  department_Technology   1850 non-null   uint8
# dtypes: float64(1), int64(3), object(2), uint8(5)
# memory usage: 95.9+ KB

# %%
#Checking the correlation of the data
new_df.corr()
# Out:
# /tmp/ipykernel_8358/1206148579.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_df.corr()
#                         course_id      year  enrollment_count  post_score  \
# course_id                1.000000 -0.008122         -0.018053   -0.028502
# year                    -0.008122  1.000000          0.018733    0.011042
# enrollment_count        -0.018053  0.018733          1.000000    0.007179
# post_score              -0.028502  0.011042          0.007179    1.000000
# department_Engineering  -0.016817 -0.026117         -0.210314   -0.001932
# department_Math          0.001617 -0.013192          0.041576    0.013778
# department_Mathematics   0.048467  0.020232          0.015879   -0.038764
# department_Science       0.025020 -0.037057         -0.292638   -0.008080
# ...

# %%
#Drawing the heatmap
corr = new_df.corr(method = "spearman")
sns.heatmap(corr,annot = True)
plt.show()
# Out:
# /tmp/ipykernel_8358/2083935879.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = new_df.corr(method = "spearman")

# %% [markdown]
# ## Data Visualization

# %%
#Checking the visualization of course type and pre_score
sns.relplot(x = "course_type", y = "pre_score",data = df, kind = "line")

# %%
#Checking the visualization of course type and post_score
sns.relplot(x = "course_type", y = "post_score",data = df, kind = "line")

# %%
#Checking which department had the highest enrollment
sns.relplot(x = "course_type", y = "department_Engineering",data = new_df, kind = "line")

# %%
x = new_df.drop("course_type", axis = 1)
y = new_df["course_type"]

print("Split done")
# Out:
# Split done

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2)

print("Split done")
# Out:
# Split done

# %%
from sklearn.tree import DecisionTreeRegressor

model =  DecisionTreeRegressor()
model.fit(x_train,y_train)


print(model.score(x_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       1 from sklearn.tree import DecisionTreeRegressor
#       3 model =  DecisionTreeRegressor()
# ----> 4 model.fit(x_train,y_train)
#       7 print(model.score(x_test,y_test))
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/tree/_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
#    1253     return self
#
# ...
